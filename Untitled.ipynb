# %%
import os
from pytube import YouTube

def download_video(url, output_folder):
    try:
        yt = YouTube(url)
        stream = yt.streams.filter(progressive=True, file_extension="mp4").first()

        if stream:
            file_name = os.path.join(output_folder, f"{yt.title}.mp4")

            stream.download(output_path=output_folder)
            print(f"Downloaded: {yt.title}")

        else:
            print(f"No suitable stream found for {url}")

    except Exception as e:
        print(f"Error downloading {url}: {str(e)}")

def main():
    input_file = 'video_urls.txt'  # Replace with the path to your text file
    output_folder = 'downloaded_videos'  # Replace with the desired output folder where the downloaded videos will be saved

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Read URLs from the input file and download each video
    with open(input_file, 'r') as file:
        urls = file.read().splitlines()
        for url in urls:
            download_video(url, output_folder)

if __name__ == "__main__":
    main()
# Out:
# Downloaded: How To M0D SNOW using MT Manager (VIP) | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How To M0D SNOW using MT Manager (VIP) | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How To M0D SNOW using MT Manager (VIP) | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D Net Optimizer using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Net Optimizer using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Net Optimizer using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D VPNify using MT Manager | Reverse Smali Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D VPNify using MT Manager | Reverse Smali Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D VPNify using MT Manager | Reverse Smali Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D ProCCD using MT Manager(VIP) | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D ProCCD using MT Manager(VIP) | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D ProCCD using MT Manager(VIP) | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D Capcut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D Capcut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D Capcut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D One Booster using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D One Booster using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D One Booster using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D TimeCut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D TimeCut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D TimeCut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D One Security using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D One Security using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D One Security using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D Video Compressor using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D Video Compressor using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D Video Compressor using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔓
# Downloaded: How to M0D Inshot using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Inshot using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Inshot using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Pixelcut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Pixelcut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Pixelcut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Photo Lab using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Photo Lab using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Photo Lab using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D MiX Launcher using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D MiX Launcher using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D MiX Launcher using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D PowerAmp using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D PowerAmp using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D PowerAmp using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Voice Changer using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Voice Changer using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Voice Changer using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D BitDefender using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D BitDefender using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D BitDefender using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avast CleanUp using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avast CleanUp using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avast CleanUp using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avast One using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avast One using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avast One using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avira Security using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avira Security using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avira Security using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Splayer using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Splayer using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Splayer using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How To M0D MX Player Pro using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How To M0D MX Player Pro using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How To M0D MX Player Pro using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avast Antivirus using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avast Antivirus using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Avast Antivirus using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D PlayIt using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D PlayIt using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D PlayIt using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D RaR using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D RaR using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D RaR using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D SkyVPN using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D SkyVPN using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D SkyVPN using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How To M0D SD Maid using MT Manager | Smali Reverse Engineering | Education Purpose Only🔐
# Downloaded: How To M0D SD Maid using MT Manager | Smali Reverse Engineering | Education Purpose Only🔐
# Downloaded: How To M0D SD Maid using MT Manager | Smali Reverse Engineering | Education Purpose Only🔐
# Downloaded: How to M0D ActionDirector using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D ActionDirector using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D ActionDirector using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D VivaCut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D VivaCut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D VivaCut using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How To M0D Carly-OBD2 Car Scanner | MT Manager | Smali Reverse Engineering | Educational Purpose🔐
# Downloaded: How To M0D Carly-OBD2 Car Scanner | MT Manager | Smali Reverse Engineering | Educational Purpose🔐
# Downloaded: How To M0D Carly-OBD2 Car Scanner | MT Manager | Smali Reverse Engineering | Educational Purpose🔐
# Downloaded: How to M0D Youtools using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔐
# Downloaded: How to M0D Youtools using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔐
# Downloaded: How to M0D Youtools using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔐
# Downloaded: How to M0D X-Secure VPN using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D X-Secure VPN using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D X-Secure VPN using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How To M0D MStudio using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How To M0D MStudio using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How To M0D MStudio using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Edjing Mix using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Edjing Mix using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Edjing Mix using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Footej Camera 2 using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Footej Camera 2 using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Footej Camera 2 using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D 1.1.1.1 VPN using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D 1.1.1.1 VPN using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D 1.1.1.1 VPN using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D VN Video Editor using MT Manager|Smali Reverse Engineering|Educational Purpose Only🔐
# Downloaded: How to M0D VN Video Editor using MT Manager|Smali Reverse Engineering|Educational Purpose Only🔐
# Downloaded: How to M0D VN Video Editor using MT Manager|Smali Reverse Engineering|Educational Purpose Only🔐
# Downloaded: New Method M0d PowerDirector using MT Manager|Smali Reverse Engineering|Educational Purpose Only🔐
# Downloaded: New Method M0d PowerDirector using MT Manager|Smali Reverse Engineering|Educational Purpose Only🔐
# Downloaded: New Method M0d PowerDirector using MT Manager|Smali Reverse Engineering|Educational Purpose Only🔐
# Downloaded: How to M0D CCleaner using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D CCleaner using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D CCleaner using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔐
# Downloaded: How to M0D Filmora Using Mt Manager | Smali Reverse Engineering | Educational Purpose Only 🔐
# Downloaded: How to M0D Filmora Using Mt Manager | Smali Reverse Engineering | Educational Purpose Only 🔐
# Downloaded: How to M0D Filmora Using Mt Manager | Smali Reverse Engineering | Educational Purpose Only 🔐
# Downloaded: How to M0D VPN.lat using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔐
# Downloaded: How to M0D VPN.lat using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔐
# Downloaded: How to M0D VPN.lat using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔐
# Downloaded: New Method M0D Niagara Launcher using MT Manager| Smali Reverse Engineering| Educational Purpose 🔐
# Downloaded: New Method M0D Niagara Launcher using MT Manager| Smali Reverse Engineering| Educational Purpose 🔐
# Downloaded: New Method M0D Niagara Launcher using MT Manager| Smali Reverse Engineering| Educational Purpose 🔐
# Downloaded: How to M0D FAB AdBlocker Browser use MT Manager| Smali Reverse Engineering| Educational Purpose Only
# Downloaded: How to M0D FAB AdBlocker Browser use MT Manager| Smali Reverse Engineering| Educational Purpose Only
# Downloaded: How to M0D FAB AdBlocker Browser use MT Manager| Smali Reverse Engineering| Educational Purpose Only
# Downloaded: How to M0D Photomath using MT Manager |  Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D Photomath using MT Manager |  Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D Photomath using MT Manager |  Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D Photo Editor using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔒
# Downloaded: How to M0D Photo Editor using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔒
# Downloaded: How to M0D Photo Editor using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔒
# Downloaded: How to M0D TagsYou using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D TagsYou using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D TagsYou using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D AutoResponder for WA using MT Manager | Smali Reverse Engineering | Educational Purpose 🔒
# Downloaded: How to M0D AutoResponder for WA using MT Manager | Smali Reverse Engineering | Educational Purpose 🔒
# Downloaded: How to M0D AutoResponder for WA using MT Manager | Smali Reverse Engineering | Educational Purpose 🔒
# Downloaded: How to M0D Malwarebytes using MT Manager | Smali Reverse Engineering | Educational Purpose Only
# Downloaded: How to M0D Malwarebytes using MT Manager | Smali Reverse Engineering | Educational Purpose Only
# Downloaded: How to M0D Malwarebytes using MT Manager | Smali Reverse Engineering | Educational Purpose Only
# Downloaded: How to M0D DualSpace using MT Manager | Smali Reverse Engineering | Educational Purpose Only
# Downloaded: How to M0D DualSpace using MT Manager | Smali Reverse Engineering | Educational Purpose Only
# Downloaded: How to M0D DualSpace using MT Manager | Smali Reverse Engineering | Educational Purpose Only
# Downloaded: How to M0D PowerDirector using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D PowerDirector using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D PowerDirector using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D Niagara Launcher using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D Niagara Launcher using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D Niagara Launcher using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D PicsArt using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔒
# Downloaded: How to M0D PicsArt using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔒
# Downloaded: How to M0D PicsArt using MT Manager | Smali Reverse Engineering | Educational Purpose Only 🔒
# Downloaded: How to M0D PhotoRoom using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D PhotoRoom using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D PhotoRoom using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D YouCam Makeup using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D YouCam Makeup using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D YouCam Makeup using MT Manager | Smali Reverse Engineering | Educational Purpose Only🔒
# Downloaded: How to M0D Telegram to Premium | Smali Reverse Engineering | Using MT Manager | Educational Purpose.
# Downloaded: How to M0D Telegram to Premium | Smali Reverse Engineering | Using MT Manager | Educational Purpose.
# Downloaded: How to M0D Telegram to Premium | Smali Reverse Engineering | Using MT Manager | Educational Purpose.
# Downloaded: How to M0D YouCam Perfect | Educational Purpose Only | Using MT Manager | Smali Reverse Engineering
# Downloaded: How to M0D YouCam Perfect | Educational Purpose Only | Using MT Manager | Smali Reverse Engineering
# Downloaded: How to M0D YouCam Perfect | Educational Purpose Only | Using MT Manager | Smali Reverse Engineering
# Downloaded: Light Of Thel Sea-1 (Bug or bot)
# Downloaded: Light Of Thel Sea-1 (Bug or bot)
# Downloaded: Light Of Thel Sea-1 (Bug or bot)

# %%
pip install pytube
# Out:
# Collecting pytubeNote: you may need to restart the kernel to use updated packages.
#
#   Using cached pytube-15.0.0-py3-none-any.whl (57 kB)
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0
